# %%
import spacy
from sklearn.cluster import KMeans
from sklearn.feature_extraction import DictVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import normalize
from collections import defaultdict
from tqdm import tqdm
import pickle

# %%
# Settings
ROOTC = "../corpus/"   # root files corpus
ROOTP = "../pickles/"  # root files pickles

# %% [markdown]
# **Preprocesamiento del corpus**

# %%
def preProcessing(ncorpus):
    """
    input: corpus name
    output: tokenizer doc, without stop-words and DIGITO word
    """
    corpus = ROOTC + ncorpus
    nlp = spacy.load('es')
    
    # See https://spacy.io/usage/spacy-101#pipelines
    # disable pipeline from spacy
    pipe = ["ner"]

    tokenizer_doc = []
    with open(corpus) as fd:
        for document in tqdm(fd.readlines()):
            document = document.strip()
            nlp.max_length = max(len(document), nlp.max_length)
            
            # nlp create doc object(token sequence)
            tokens = [ token for token in nlp(document, disable=pipe) 
                       if not ((token.is_stop) or (token.text == 'DIGITO'))
                     ]
            
            # delete documents long less than 8
            if len(tokens) > 8:
                tokenizer_doc.append(tokens)
    return tokenizer_doc

# %% [markdown]
# **Diccionario de caracterisiticas**

# %%
# See https://spacy.io/api/token

def featuresDic(tokenizer):
    to_vector = []
    words = []
    for document in tokenizer:
        has_prev = False
        for token in document:
            features = {}
            features['word'] = token.text
            features['pos'] = token.pos_
            features['lemma'] = token.lemma_                        
            features['is_lower'] = token.is_lower
            
            # dependence tripla: TOKEN has a DEP_ relationship with HEAD
            features['dt'] = '_D_' + token.dep_ + '_H_' + token.head.orth_
            if has_prev:
              features['pre_word'] = token.nbor(-1).orth_
            try:
              features['pos_word'] = token.nbor().orth_
            except IndexError:
              pass
            has_prev = True
            to_vector.append(features)
            words.append(token.text)
    return to_vector, words

# %% [markdown]
# **Vectorizado de las caracteristicas**

# %%
# See https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.DictVectorizer.html
def vectorizer(features):
    v = DictVectorizer()
    X = v.fit_transform(features)
    return X

# %% [markdown]
# **Reduccion de dimensionalidad**

# %%
# See https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.TruncatedSVD.html#sklearn.decomposition.TruncatedSVD
def reductionDim(v, n, n_iter):
    svd = TruncatedSVD(n_components=n, n_iter=n_iter)
    Y = svd.fit_transform(v)
    return Y

# %% [markdown]
# **Clustering**

# %%
# See https://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html
def clustering(v, n_clusters, n_iter):
    kmeans = KMeans(n_clusters=n_clusters, max_iter=n_iter)
    kmeans.fit(v)
    v_labels = kmeans.predict(v)
    return kmeans, v_labels

# %% [markdown]
# **====================================================================================================================**

# %%
tokenizers = preProcessing("xaa")
# Out:
# 100%|██████████| 7277/7277 [00:49<00:00, 147.98it/s]

# %%
to_v, w = featuresDic(tokenizers)

# %%
dic = newFeaturesDic(tokenizers[:200])

# %%
k,v = new(dic)

# %%
x = vectorizer(v)

# %%
v_rd = reductionDim(x, 23, 10)

# %%
kmeans, labels = clustering(v_rd, 82, 230)

# %%
c = list(zip(labels, k))

# %%
clustersNEW = defaultdict(set)
for idc, word in c:
    clustersNEW[idc].add(word)

# %%
clusters
# Out:
# defaultdict(set,
#             {52: {'actuaciones',
#               'animadora',
#               'artículo',
#               'bate',
#               'canciones',
#               'convertirse',
#               'datos',
#               'empleado',
#               'exclusión',
#               'fuerza',
#               'jóvenes',
#               'letras',
#               'lugares',
#               'motivo',
#               'orígenes',
#               'país',
#               'pop',
#               'presencia',
#               'redactor',
#               'resolución',
#               'salón',
#               'álbum'},
#              24: {'alrededores',
#               'amiloides',
#               'artículos',
#               'asociación',
#               'aspecto',
#               'bases',
#               'capa',
#               'competencia',
#               'cuerpos',
#               'delegados',
#               'desierto',
#               'director',
#               'divergencias',
#               'equipo',
#               'extranjero',
#               'flete',
#               'frecuencia',
#               'hifas',
#               'hits',
#               'hongos',
#               'líder',
#               'micorrizas',
#               'obras',
#               'pareja',
#               'países',
#               'piramidales',
#               'problemas',
#               'pueblo',
#               'relación',
#               'reunión',
#               'rosa',
#               'río',
#               'siglo',
#               'sindicalismo',
#               'supervivencia',
#               'tono',
#               'torneo',
#               'trabajos',
#               'época'},
#              26: {'agrietado',
#               'anotadas',
#               'arseniatos',
#               'bizantino',
#               'castaños',
#               'completos',
#               'emancipada',
#               'estrechos',
#               'excepcional',
#               'firme',
#               'gelatinizada',
#               'goles',
#               'hueco',
#               'industriales',
#               'kmDIGITO',
#               'm',
#               'minero',
#               'nacionales',
#               'oceanográfica',
#               'oriental',
#               'osos',
#               'revolucionario',
#               'rusa',
#               'translúcidas',
#               'umber',
#               'zinovievista'},
#              1: {'y'},
#              23: {'Crece',
#               'Entra',
#               'Militó',
#               'abstuvo',
#               'basándose',
#               'conoce',
#               'convirtió',
#               'crece',
#               'cree',
#               'descubierta',
#               'ejercer',
#               'entró',
#               'fundado',
#               'habita',
#               'ilustró',
#               'interesarse',
#               'introdujo',
#               'jugando',
#               'jugó',
#               'live',
#               'milita',
#               'muestra',
#               'muestran',
#               'obtenido',
#               'pagar',
#               'permanecen',
#               'permaneció',
#               'produce',
#               'profesa',
#               'publica',
#               'rockalbum',
#               'separó',
#               'sitúa',
#               'terminar',
#               'transformado',
#               'ubica',
#               'vivía',
#               'votaron'},
#              15: {'anillo',
#               'bordes',
#               'ciudad',
#               'células',
#               'e',
#               'islas',
#               'láminas',
#               'ocasiones',
#               'periódico',
#               'ruso',
#               'sindicalista',
#               'superficie',
#               'tamaño',
#               'vida'},
#              5: {'Apodado',
#               'Desaprobado',
#               'Habilitado',
#               'Nacido',
#               'abruptamente',
#               'aceptable',
#               'adulta',
#               'afinado',
#               'africano',
#               'afroamericanos',
#               'alargada',
#               'amarillentas',
#               'amarronados',
#               'americano',
#               'amerimuscaria',
#               'anarquizante',
#               'asiáticos',
#               'atestadas',
#               'atractivo',
#               'austríaco',
#               'azurita',
#               'bajas',
#               'barbero',
#               'beneficiosa',
#               'blancos',
#               'bobinados',
#               'brochantita',
#               'capacitados',
#               'central',
#               'clasificado',
#               'colgado',
#               'compuesto',
#               'conectados',
#               'conocido',
#               'constituido',
#               'cortas',
#               'cubierta',
#               'delgadas',
#               'descargado',
#               'destructivos',
#               'deñl',
#               'diagonal',
#               'dicha',
#               'disidente',
#               'ejecutivo',
#               'elevada',
#               'elípticas',
#               'esenciales',
#               'estudioso',
#               'extensa',
#               'extraordinaria',
#               'ferroviaria',
#               'fijadas',
#               'fundamental',
#               'futuros',
#               'globalmente',
#               'gracias',
#               'hidroxilado',
#               'homónimo',
#               'hábil',
#               'imparables',
#               'importantes',
#               'independenciadel',
#               'inicial',
#               'inmensa',
#               'intelectual',
#               'internas',
#               'internationalistes',
#               'irregulares',
#               'lejano',
#               'locales',
#               'localizadas',
#               'madura',
#               'mecánica',
#               'micelio',
#               'micologista',
#               'micorriza',
#               'micrómetros',
#               'mojado',
#               'monotonal',
#               'monumental',
#               'máxima',
#               'médica',
#               'name',
#               'neozelandesa',
#               'nombrada',
#               'obligatoria',
#               'obrera',
#               'ocasionalmente',
#               'orgánica',
#               'orgánicos',
#               'parisinos',
#               'participantes',
#               'patagónica',
#               'pegajosa',
#               'pequeños',
#               'piel',
#               'planeado',
#               'pleno',
#               'popular',
#               'postal',
#               'presentada',
#               'primordial',
#               'principal',
#               'privilegiadas',
#               'profundas',
#               'proletariado',
#               'prolétarienne',
#               'próximas',
#               'raro',
#               'real',
#               'rebautizada',
#               'recibidas',
#               'recogidas',
#               'reconocida',
#               'referida',
#               'reformistas',
#               'reforzado',
#               'revolucionarias',
#               'roja',
#               'rugoso',
#               'rusos',
#               'sagrada',
#               'seco',
#               'secundario',
#               'seguros',
#               'separada',
#               'simbiótica',
#               'songs',
#               'south',
#               'soviético',
#               'straw',
#               'subpellis',
#               'suficientes',
#               'suizo',
#               'superior',
#               'suprapellis',
#               'surcos',
#               'taxonómico',
#               'teatral',
#               'tensos',
#               'translated',
#               'transparente',
#               'trotskista',
#               'truncadas',
#               'très',
#               'turística',
#               'turísticos',
#               'tácticas',
#               'vasta',
#               'verosímil',
#               'vivo',
#               'with'},
#              78: {'Anima',
#               'Aparecerían',
#               'Apoya',
#               'Clasificaron',
#               'Defiende',
#               'Destacan',
#               'Finalizado',
#               'Firmaron',
#               'Formaba',
#               'Ocupa',
#               'Organiza',
#               'Produce',
#               'Recibe',
#               'Viajan',
#               'abandonando',
#               'abrupta',
#               'acepta',
#               'acercarse',
#               'admitido',
#               'afirmando',
#               'album',
#               'alcanzar',
#               'aleja',
#               'anular',
#               'aporta',
#               'aportan',
#               'apoya',
#               'apoyan',
#               'aprende',
#               'aprobar',
#               'aprueba',
#               'asegura',
#               'atienden',
#               'beneficia',
#               'cargado',
#               'coincide',
#               'communiste',
#               'conocida',
#               'consagró',
#               'considerada',
#               'consiguió',
#               'contribuir',
#               'creía',
#               'critica',
#               'cruzaron',
#               'cuesta',
#               'decayó',
#               'decide',
#               'defiende',
#               'denuncia',
#               'derrotó',
#               'desarrolla',
#               'desarrolló',
#               'dirigiéndose',
#               'dándole',
#               'efectuar',
#               'emitía',
#               'emplazaba',
#               'emplea',
#               'encaja',
#               'encontrar',
#               'encuentran',
#               'enfrentaron',
#               'enrolla',
#               'entabla',
#               'entra',
#               'especificó',
#               'examinó',
#               'excluyeron',
#               'existía',
#               'extienden',
#               'firmando',
#               'flavoconia',
#               'formalizar',
#               'formando',
#               'franchetii',
#               'fusca',
#               'grabar',
#               'guía',
#               'habitada',
#               'habitados',
#               'impedir',
#               'impide',
#               'inauguró',
#               'incluyendo',
#               'incorpora',
#               'indican',
#               'instalar',
#               'intentaban',
#               'intentó',
#               'interesan',
#               'jugará',
#               'jugaría',
#               'justificó',
#               'life',
#               'list',
#               'llamó',
#               'llavar',
#               'malaquita',
#               'manteniendo',
#               'mantiene',
#               'mantuvo',
#               'medir',
#               'mide',
#               'militó',
#               'minimizar',
#               'notado',
#               'obtiene',
#               'organizar',
#               'ostentaría',
#               'pasó',
#               'pensaba',
#               'perdieron',
#               'permitía',
#               'pide',
#               'prefacia',
#               'presentó',
#               'presidiendo',
#               'presta',
#               'preveía',
#               'prima',
#               'proporciona',
#               'propusieron',
#               'publicar',
#               'queda',
#               'quedar',
#               'quería',
#               'realiza',
#               'recoger',
#               'reemplazado',
#               'reemplazar',
#               'remarca',
#               'rendirá',
#               'representado',
#               'reside',
#               'resulta',
#               'retoma',
#               'reunió',
#               'revise',
#               'reúnen',
#               'rojizo',
#               'russe',
#               'seguir',
#               'siguen',
#               'sugiere',
#               'together',
#               'toma',
#               'tornería',
#               'trazará',
#               'unen',
#               'visto',
#               'viviendo',
#               'volviéndose',
#               'vuelve',
#               'ได'},
#              14: {'acusaciones',
#               'agencias',
#               'amigos',
#               'apoyo',
#               'aumento',
#               'ayuda',
#               'ayudante',
#               'bosque',
#               'bulto',
#               'centenar',
#               'centristas',
#               'colonia',
#               'concepción',
#               'conciencia',
#               'contrario',
#               'correcciones',
#               'cotejos',
#               'crítico',
#               'desarrollo',
#               'despachos',
#               'dificultades',
#               'eliminación',
#               'existencia',
#               'favor',
#               'finales',
#               'fundadores',
#               'grabación',
#               'grabado',
#               'hiladora',
#               'holotipo',
#               'influencias',
#               'jefe',
#               'julion',
#               'lecciones',
#               'límites',
#               'marzo',
#               'mayo',
#               'medida',
#               'millones',
#               'milímetros',
#               'misión',
#               'mm',
#               'mosca',
#               'márgenes',
#               'necesidades',
#               'notas',
#               'océanos',
#               'oficio',
#               'padres',
#               'papel',
#               'partida',
#               'personajes',
#               'promedio',
#               'purga',
#               'remanecientes',
#               'récord',
#               'shows',
#               'tesis',
#               'tipos',
#               'versiones',
#               'zigóptero',
#               'áreas'},
#              21: {'adhesión',
#               'algodón',
#               'calderería',
#               'carbonato',
#               'construir',
#               'coníferas',
#               'encuesta',
#               'espesor',
#               'frosardismo',
#               'fungi',
#               'fútbol',
#               'inteligencia',
#               'malversaciones',
#               'mano',
#               'miradas',
#               'odonato',
#               'paja',
#               'plantas',
#               'posguerra',
#               'prefacios',
#               'rugosidades',
#               'secundaria',
#               'televisión',
#               'temporada',
#               'visitantes'},
#              6: {'Abu',
#               'Adrien',
#               'Alexei',
#               'Alta',
#               'Amédée',
#               'Andrès',
#               'Angeles',
#               'Angels',
#               'Aprovecha',
#               'Argentina',
#               'Athiwara',
#               'Austria',
#               'Bodyslam',
#               'Boris',
#               'Bugs',
#               'Bélgica',
#               'Cachin',
#               'Calopterix',
#               'Calopterygidae',
#               'Campeón',
#               'Camus',
#               'Caraglio',
#               'Cardinals',
#               'Carrie',
#               'Castleton',
#               'Central',
#               'Charlesworth',
#               'Christian',
#               'Cibaeñas',
#               'Comédie',
#               'Coyoacan',
#               'Créteil',
#               'Dai',
#               'David',
#               'Democrática',
#               'Dhabi',
#               'Dirección',
#               'Domingo',
#               'Dommanget',
#               'Donovan',
#               'Droylsden',
#               'Dunois',
#               'Egon',
#               'Estación',
#               'Eto',
#               'Fernand',
#               'Française',
#               'Frossard',
#               'Gang',
#               'Gaston',
#               'Gauche',
#               'Geneviève',
#               'Geoff',
#               'Give',
#               'Gras',
#               'Greco',
#               'Greta',
#               'Grigori',
#               'Guzmán',
#               'Harry',
#               'Heras',
#               'Horak',
#               'Huapi',
#               'Hudson',
#               'III',
#               'Ibsen',
#               'Ignace',
#               'Impossibles',
#               'Independiente',
#               'Inglaterra',
#               'Intercontinental',
#               'Internacionales',
#               'It',
#               'José',
#               'Kun',
#               'Kurt',
#               'L',
#               'Laborista',
#               'Lagos',
#               'Lancashire',
#               'Landau',
#               'Lilas',
#               'Lopera',
#               'Loriot',
#               'Losovski',
#               'Louis',
#               'Louisa',
#               'Mamore',
#               'Maurice',
#               'Memorial',
#               'Monmousseau',
#               'Montagne',
#               'Monte',
#               'Murmansk',
#               'México',
#               'Nai',
#               'National',
#               'Naval',
#               'Naville',
#               'Nikolái',
#               'Nin',
#               'Niyai',
#               'Not',
#               'PCF',
#               'Pampa',
#               'Patterson',
#               'Pepper',
#               'Potosí',
#               'Profesor',
#               'Prolétarienne',
#               'R',
#               'Radek',
#               'Rambla',
#               'Raymond',
#               'Reiss',
#               'René',
#               'Roberto',
#               'Rodham',
#               'Rolland',
#               'Rue',
#               'Rushmore',
#               'SCRA',
#               'Sainte',
#               'San',
#               'Sano',
#               'Santiago',
#               'Sección',
#               'Sheikh',
#               'Souvarine',
#               'Stalin',
#               'Temps',
#               'The',
#               'Thep',
#               'Thevenet',
#               'Tigres',
#               'Tito',
#               'Tomás',
#               'Tulloss',
#               'Tungus',
#               'Validae',
#               'Vanyady',
#               'Veloz',
#               'Vergeat',
#               'Victor',
#               'Wave',
#               'Wellington',
#               'Yessey',
#               'Yugoslavia',
#               'Zayed',
#               'du',
#               'flycap',
#               'guilty',
#               'nouveaux',
#               'plao',
#               'virgo',
#               'Águilas',
#               'Álvarez',
#               'Éscuela',
#               'à',
#               'Λίθος',
#               'Дунай',
#               'Ессей',
#               'Острова',
#               'ยาย',
#               'ละ',
#               'เทพน'},
#              29: {'I',
#               'Inicialmente',
#               'Macroscópicamente',
#               'O',
#               'Suele',
#               'allá',
#               'anteriormente',
#               'atrás',
#               'claramente',
#               'completamente',
#               'deberá',
#               'debería',
#               'densamente',
#               'diecisiete',
#               'diez',
#               'diversas',
#               'enfrentándose',
#               'explicando',
#               'finalmente',
#               'in',
#               'intensamente',
#               'justo',
#               'lentamente',
#               'libremente',
#               'loa',
#               'madre',
#               'misteriosamente',
#               'moderadamente',
#               'mouvement',
#               'mutuamente',
#               'normalmente',
#               'notablemente',
#               'oficialmente',
#               'on',
#               'posteriormente',
#               'radicalmente',
#               'realmente',
#               'reformar',
#               'rápidamente',
#               'suavemente',
#               'totalmente',
#               'típicamente',
#               'u',
#               'À',
#               'ซ',
#               'ด',
#               'นาย',
#               'ล',
#               'อน',
#               'า',
#               'เสนาะ'},
#              2: {'XVII',
#               'XVIII',
#               'actividad',
#               'ajuste',
#               'amante',
#               'amerindios',
#               'amistad',
#               'anarcosindicalistas',
#               'anarquismo',
#               'aniones',
#               'anunciación',
#               'aro',
#               'arseniato',
#               'arte',
#               'asociasiones',
#               'asunto',
#               'atractivos',
#               'auge',
#               'añadidura',
#               'biógrafo',
#               'bolas',
#               'bracket',
#               'bulbo',
#               'capacidades',
#               'cargo',
#               'carreras',
#               'casquillo',
#               'ceremonia',
#               'chismes',
#               'ciervos',
#               'clases',
#               'cobrería',
#               'combate',
#               'combinación',
#               'compañera',
#               'compuestos',
#               'concurso',
#               'condición',
#               'congresos',
#               'conjunto',
#               'contactos',
#               'continuación',
#               'contrato',
#               'cooperación',
#               'cretense',
#               'crisocola',
#               'crítica',
#               'cuentas',
#               'cuero',
#               'cultura',
#               'delegado',
#               'depresión',
#               'diablo',
#               'disco',
#               'discusiones',
#               'división',
#               'ectomicorriza',
#               'eje',
#               'elipsoidales',
#               'embarcadero',
#               'equipos',
#               'estafeta',
#               'estructuras',
#               'explicaciones',
#               'exponerlas',
#               'exterior',
#               'extremidades',
#               'far',
#               'formación',
#               'formas',
#               'formato',
#               'fosfatos',
#               'gira',
#               'griego',
#               'gris',
#               'grisáceas',
#               'grosero',
#               'grosor',
#               'grupos',
#               'guardia',
#               'habitantes',
#               'hialinos',
#               'historia',
#               'importancia',
#               'individualismo',
#               'informe',
#               'instancia',
#               'interés',
#               'jardinero',
#               'juegos',
#               'laminillas',
#               'lamélulas',
#               'lanzador',
#               'litos',
#               'llanura',
#               'manifiesto',
#               'marido',
#               'material',
#               'matrimonio',
#               'mayorías',
#               'mechones',
#               'mediano',
#               'meses',
#               'meseta',
#               'minorías',
#               'movimientos',
#               'muerte',
#               'mundo',
#               'naturaleza',
#               'nieto',
#               'núcleo',
#               'número',
#               'ovoide',
#               'padre',
#               'paredes',
#               'partial',
#               'piedra',
#               'plano',
#               'premio',
#               'profundidad',
#               'programa',
#               'publicaciones',
#               'puntas',
#               'ramal',
#               'relaciones',
#               'representante',
#               'requisito',
#               'ribera',
#               'régimen',
#               'secretario',
#               'sello',
#               'semanario',
#               'series',
#               'servicios',
#               'similitud',
#               'socialismo',
#               'soldadura',
#               'sombreros',
#               'suscripción',
#               'talleres',
#               'taxón',
#               'temporadas',
#               'texto',
#               'tierra',
#               'tipo',
#               'tirolita',
#               'transversales',
#               'triunfo',
#               'trotskismo',
#               'turnos',
#               'vegetal',
#               'venta',
#               'villa',
#               'visas',
#               'visitadora',
#               'you',
#               'zonas',
#               'éxito',
#               'พอ',
#               'ม',
#               'ส',
#               'หร',
#               'เบ',
#               'เปล'},
#              76: {'Aula',
#               'Barón',
#               'Black',
#               'Boletín',
#               'Departamento',
#               'Estadio',
#               'Inter',
#               'Mazembe',
#               'Museo',
#               'Nahuel',
#               'Parque',
#               'Testamento'},
#              28: {'Albert',
#               'Argo',
#               'Armada',
#               'Borís',
#               'Copa',
#               'Cruz',
#               'Deseado',
#               'Dique',
#               'Europa',
#               'Griot',
#               'Hills',
#               'Historia',
#               'ISR',
#               'Isla',
#               'Keystone',
#               'Music',
#               'N',
#               'Nacional',
#               'Oudemansiella',
#               'Ridley',
#               'Rusia',
#               'Samuel',
#               'Sieva',
#               'Suiza',
#               'VO',
#               'and',
#               'of',
#               'Étudiants'},
#              39: {'Amanitaceae',
#               'Ejecutivo',
#               'Ferrocarril',
#               'Lenin',
#               'Liga',
#               'Limacella',
#               'Mauá',
#               'Molinier',
#               'Nothofagus',
#               'París',
#               'Pierre',
#               'Pollitt',
#               'Real',
#               'Révolution',
#               'SFIC',
#               'Silverio',
#               'Sur',
#               'Treint',
#               'Vie',
#               'York',
#               'Zelanda',
#               'Zinóviev',
#               'the'},
#              70: {'común', 'construido', 'político', 'ubicada'},
#              41: {'abuelo',
#               'arcángel',
#               'borde',
#               'camerunés',
#               'canon',
#               'caso',
#               'clima',
#               'crecimiento',
#               'dialecto',
#               'equipaje',
#               'espécimen',
#               'funk',
#               'furgón',
#               'hombre',
#               'indirecto',
#               'interesado',
#               'libro',
#               'oro',
#               'paraje',
#               'petit',
#               'responsable',
#               'sitio',
#               'territorio',
#               'típico',
#               'valle',
#               'área'},
#              38: {'Anaheim',
#               'Autónoma',
#               'Balón',
#               'Buques',
#               'Clubes',
#               'Comisión',
#               'DIMAT',
#               'Díez',
#               'Evangelista',
#               'Francesa',
#               'II',
#               'Ingalls',
#               'Krai',
#               'Ligas',
#               'Lille',
#               'Magna',
#               'Marbán',
#               'Mundial',
#               'Pedro',
#               'Phalloides',
#               'Prado',
#               'Provincia',
#               'Rosa',
#               'Servicio',
#               'casa',
#               'dessus'},
#              20: {'afiliación',
#               'canción',
#               'capital',
#               'conexión',
#               'definición',
#               'desembocadura',
#               'dictadura',
#               'enseñanza',
#               'espalda',
#               'estancia',
#               'financiación',
#               'fotosíntesis',
#               'herramienta',
#               'izquierda',
#               'lengua',
#               'literatura',
#               'lucha',
#               'madures',
#               'minoría',
#               'mêlée',
#               'orilla',
#               'participación',
#               'pintura',
#               'planta',
#               'pradera',
#               'prensa',
#               'primavera',
#               'reacción',
#               'región',
#               'reparación',
#               'representación',
#               'revista',
#               'ruptura',
#               'sinonimia',
#               'tennantita',
#               'tribu',
#               'unanimidad',
#               'unión',
#               'verruga',
#               'visión',
#               'votación',
#               'voz'},
#              42: {'abetos',
#               'adicionales',
#               'algodonosos',
#               'amiloide',
#               'brillante',
#               'constituyente',
#               'contitutivo',
#               'costeras',
#               'cubiertos',
#               'departamentales',
#               'emergente',
#               'estadounidense',
#               'fructíferos',
#               'hidratado',
#               'húmedas',
#               'importante',
#               'jardín',
#               'libres',
#               'mayores',
#               'musical',
#               'oriundos',
#               'ouvrier',
#               'quebradizo',
#               'salpicado',
#               'sinónimo',
#               'sonora',
#               'unitaria'},
#              4: {'Amanita', 'Comunista', 'Oficina'},
#              36: {'Censo', 'píleo'},
#              40: {'Francia', 'Monatte', 'Unidos'},
#              10: {'abundantes',
#               'amarillo',
#               'blancas',
#               'blanco',
#               'blanquecino',
#               'bolcheviques',
#               'bulbosa',
#               'inglés',
#               'internacionales',
#               'km²',
#               'nacional',
#               'naval',
#               'obrero',
#               'pequeñas',
#               'pequeño',
#               'sindical',
#               'venenoso'},
#              22: {'acudir',
#               'adhiere',
#               'ajena',
#               'anaranjado',
#               'asistir',
#               'corresponden',
#               'delega',
#               'designa',
#               'enfrentarse',
#               'envía',
#               'expulsado',
#               'frecuentará',
#               'garantizan',
#               'habilitaban',
#               'iban',
#               'irán',
#               'lanza',
#               'leer',
#               'llamada',
#               'llegan',
#               'llevada',
#               'llevan',
#               'niegan',
#               'opuso',
#               'parecerse',
#               'pertenecían',
#               'reemplaza',
#               'transferido',
#               'viajan',
#               'volver'},
#              3: {'a'},
#              51: {'agua',
#               'basidiomiceto',
#               'cabo',
#               'cargas',
#               'carne',
#               'carrera',
#               'castaño',
#               'comité',
#               'desacuerdo',
#               'dirigentes',
#               'idioma',
#               'miembro',
#               'movimiento',
#               'publicación',
#               'socialistas',
#               'tomo',
#               'viajes',
#               'árboles',
#               'อ'},
#              45: {'alistamiento',
#               'caballito',
#               'cosecretario',
#               'cutícula',
#               'estaciones',
#               'hijos',
#               'historiador',
#               'honor',
#               'indicación',
#               'iniciativa',
#               'isleños',
#               'jugador',
#               'materiales',
#               'nivel',
#               'politburó',
#               'soldados'},
#              71: {'Au',
#               'Congo',
#               'Irineu',
#               'Komintern',
#               'Licey',
#               'Pacífico',
#               'Tirol'},
#              27: {'campeones',
#               'comunismo',
#               'country',
#               'editor',
#               'electricidad',
#               'exámenes',
#               'huelgas',
#               'peces',
#               'principios',
#               'procedencia',
#               'razas',
#               'sindicalistas',
#               'testimonios'},
#              12: {'o'},
#              13: {'color', 'especie'},
#              9: {'australis', 'banda', 'base', 'hongo', 'tronco'},
#              75: {'Alfred', 'Stevenson', 'género'},
#              43: {'familia'},
#              35: {'adherido',
#               'circular',
#               'colabora',
#               'describió',
#               'descrita',
#               'efectúa',
#               'elegido',
#               'encontrarse',
#               'firma',
#               'forman',
#               'inaugurado',
#               'llamado',
#               'logró',
#               'miden',
#               'nombrado',
#               'ouvrière',
#               'participar',
#               'pasar',
#               'posee',
#               'presenta',
#               'significa'},
#              79: {'año',
#               'campeonato',
#               'encuentro',
#               'joven',
#               'micólogo',
#               'sindicato',
#               'sistema',
#               'teatro'},
#              33: {'Awards',
#               'Beni',
#               'Biblia',
#               'Bretaña',
#               'Bujarín',
#               'Callejas',
#               'Fayod',
#               'Inglés',
#               'Khongmalai',
#               'Kronstadt',
#               'Lepetit',
#               'Leptospermum',
#               'María',
#               'Mayo',
#               'Milán',
#               'Montevideo',
#               'Pegler',
#               'Reparaciones',
#               'Universitario',
#               'Up',
#               'Virgen',
#               'Vérité',
#               'África'},
#              56: {'crea',
#               'definió',
#               'difiere',
#               'ganaron',
#               'lanzaron',
#               'mantener',
#               'obtener',
#               'redujo',
#               'uan'},
#              48: {'forma', 'nombre'},
#              60: {'blanca', 'francés', 'µm'},
#              47: {'CGTU',
#               'Dunay',
#               'Eno',
#               'España',
#               'Franchet',
#               'Imposibles',
#               'Lena',
#               'Montrouge',
#               'Nelson',
#               'Patagónico',
#               'Rensselaer',
#               'Rotoiti',
#               'Tiziano',
#               'Turquía'},
#              30: {'On',
#               'activo',
#               'activos',
#               'agrupadas',
#               'basada',
#               'conservada',
#               'cuarto',
#               'cónico',
#               'desasparecidos',
#               'desconocida',
#               'diseminados',
#               'dispuestas',
#               'divididos',
#               'dulce',
#               'encontrado',
#               'exiliados',
#               'fallecido',
#               'frecuentes',
#               'impulsada',
#               'industrial',
#               'leninista',
#               'libre',
#               'negro',
#               'ofensivo',
#               'pagado',
#               'pronunciado',
#               'publicado',
#               'pálidas',
#               'realizada',
#               'recogidos',
#               'reelegido',
#               'rico',
#               'sexto',
#               'situadas'},
#              0: {'bandas',
#               'cm',
#               'especies',
#               'guerra',
#               'julio',
#               'norte',
#               'noviembre',
#               'restos'},
#              81: {'América',
#               'CGT',
#               'Marguerite',
#               'Moscú',
#               'Norte',
#               'Partido',
#               'Suvarin'},
#              72: {'centímetros',
#               'congreso',
#               'diciembre',
#               'margen',
#               'miembros',
#               'militantes',
#               'mineral'},
#              32: {'absorción',
#               'acción',
#               'alteración',
#               'arquitectura',
#               'clase',
#               'clasificación',
#               'conferencia',
#               'declaración',
#               'década',
#               'escritura',
#               'estructura',
#               'excepción',
#               'figura',
#               'idea',
#               'música',
#               'organización',
#               'posibilidad',
#               'punta',
#               'recuperación',
#               'represión',
#               'situación',
#               'zona'},
#              19: {'adecuado',
#               'anarquista',
#               'antiguo',
#               'compacto',
#               'comunista',
#               'convexo',
#               'cónicas',
#               'discográfico',
#               'dominicano',
#               'esféricas',
#               'estalinistas',
#               'formado',
#               'franceses',
#               'futuro',
#               'hialinas',
#               'italiano',
#               'macrospora',
#               'mejores',
#               'miel',
#               'minerales',
#               'nacido',
#               'numerosos',
#               'oscuro',
#               'parlamentario',
#               'pálido',
#               'révolutionnaires',
#               'sepia',
#               'socialistes',
#               'tailandesa',
#               'única'},
#              77: {'ascenso',
#               'cobre',
#               'ensayos',
#               'folk',
#               'librepensadores',
#               'operacionales',
#               'particulares',
#               'pesca',
#               'subcampeones',
#               'vanadatos',
#               'vuelta',
#               'zorros'},
#              54: {'Construcciones',
#               'Giacomo',
#               'Karl',
#               'Kool',
#               'Krasnoyarsk',
#               'Láptev',
#               'Macorís',
#               'Madrid',
#               'Material',
#               'Melzer',
#               'Oro',
#               'Pando',
#               'Puerto',
#               'Romain',
#               'Santo',
#               'Sousa',
#               'Strunz',
#               'Trotski'},
#              73: {'alto',
#               'altura',
#               'broches',
#               'calcio',
#               'herrero',
#               'imprenta',
#               'vacaciones'},
#              57: {'bateo',
#               'estudiantes',
#               'febrero',
#               'fructificación',
#               'observación',
#               'oxidación'},
#              55: {'asuntos',
#               'autores',
#               'ayuntamientos',
#               'bosques',
#               'correctores',
#               'crímenes',
#               'círculos',
#               'discursos',
#               'encuentros',
#               'géneros',
#               'líderes',
#               'minoritarios',
#               'niños',
#               'opositores',
#               'pasajeros',
#               'puntos',
#               'temas',
#               'yacimientos'},
#              74: {'clandestina',
#               'clásico',
#               'hidrotermales',
#               'inferior',
#               'nmombre',
#               'oficioso',
#               'rural',
#               'salido'},
#              61: {'asociado',
#               'cercano',
#               'esféricos',
#               'favorable',
#               'fijados',
#               'hostil',
#               'pacifista',
#               'perpendiculares',
#               'perteneciente',
#               'simple',
#               'tradicionales'},
#              63: {'amarillento',
#               'años',
#               'centro',
#               'esporas',
#               'estación',
#               'estipe',
#               'lago',
#               'obra'},
#              68: {'acusa',
#               'carpintería',
#               'consisten',
#               'desapareció',
#               'dimite',
#               'encargan',
#               'iba',
#               'manchan',
#               'midiendo',
#               'procede',
#               'proveyó',
#               'retira',
#               'retracta'},
#              50: {'colaboración',
#               'composición',
#               'revolución',
#               'sección',
#               'seta',
#               'volva'},
#              49: {'Armamento',
#               'Asia',
#               'Atlético',
#               'B',
#               'Béla',
#               'Françoise',
#               'Lefebvre',
#               'Martov',
#               'Mary',
#               'Tintoretto',
#               'Vaca',
#               'Young'},
#              31: {'concepto',
#               'condado',
#               'despacho',
#               'discurso',
#               'juego',
#               'mar',
#               'marco',
#               'negocio',
#               'principio',
#               'progrma',
#               'pseudónimo',
#               'reactivo',
#               'recibo',
#               'seno',
#               'sonido',
#               'tallo',
#               'tutor'},
#              7: {'asiste',
#               'cubrir',
#               'lakorn',
#               'participaron',
#               'reparar',
#               'translitera',
#               'trasfirió'},
#              8: {'ingresos'},
#              16: {'medios'},
#              59: {'hogar'},
#              34: {'localidad'},
#              17: {'A'},
#              62: {'abril',
#               'asesinato',
#               'diferencia',
#               'enero',
#               'junio',
#               'mitad',
#               'partidos',
#               'raíz',
#               'redacción',
#               'regreso',
#               'reuniones',
#               'serie',
#               'sur',
#               'verano'},
#              67: {'ancho',
#               'arena',
#               'azul',
#               'basidios',
#               'corrector',
#               'dirección',
#               'diámetro',
#               'ida',
#               'investigación',
#               'octubre',
#               'rock',
#               'trébol',
#               'verrugas'},
#              18: {'Béisbol',
#               'Hot',
#               'Lyon',
#               'Monnate',
#               'Santa',
#               'Tailandia',
#               'Tours',
#               'Zimmerwald'},
#              53: {'décimo',
#               'escasas',
#               'extranjeros',
#               'grisáceos',
#               'love',
#               'nutrientes',
#               'tecnológicas'},
#              46: {'Batalla',
#               'Conferencia',
#               'Conmebol',
#               'Cuarta',
#               'FIFA',
#               'Federación',
#               'Histoire',
#               'IC',
#               'IIIa',
#               'República',
#               'Tierra',
#               'UEFA',
#               'Universidad',
#               'Verité'},
#              65: {'buró', 'convierte', 'participa', 'puesto'},
#              37: {'grupo', 'partido'},
#              69: {'cuyo',
#               'directamente',
#               'igualmente',
#               'inicialmente',
#               'originalmente',
#               'º'},
#              58: {'comisión',
#               'creación',
#               'difusión',
#               'mayoría',
#               'necesidad',
#               'política'},
#              64: {'condujo',
#               'expcepcionalmente',
#               'llegando',
#               'llegar',
#               'naturalmente',
#               'tiende',
#               'únicamente'},
#              44: {'cadenas',
#               'contacto',
#               'cronista',
#               'destino',
#               'ell',
#               'muestras',
#               'particular',
#               'promoción',
#               'tailandés',
#               'torno',
#               'transferencias',
#               'vueltas'},
#              11: {'Rosmer'},
#              25: {'Internacional'},
#              80: {'Trotsky'},
#              66: {'Comité', 'Congreso'}})

# %%
with open(r"../pickles/clustersOLDFEAT.pkl", "wb") as fd:
    pickle.dump(clusters, fd)

# %%
to_v, w = featuresDic(tokenizers[:200])
xl = vectorizer(to_v)
v_rd = reductionDim(xl, 6, 10)
kmeans, labels = clustering(v_rd, 82, 230)
c = list(zip(labels, w))
clusters = defaultdict(set)
for idc, word in c:
    clusters[idc].add(word)
clusters
# Out:
# defaultdict(set,
#             {17: {'actuaciones',
#               'animadora',
#               'artículo',
#               'bate',
#               'cabo',
#               'canciones',
#               'cargas',
#               'convertirse',
#               'datos',
#               'director',
#               'empleado',
#               'encuentro',
#               'exclusión',
#               'forma',
#               'franceses',
#               'fuerza',
#               'inglés',
#               'jóvenes',
#               'letras',
#               'lugares',
#               'motivo',
#               'nombre',
#               'oro',
#               'orígenes',
#               'partidos',
#               'país',
#               'pop',
#               'presencia',
#               'redactor',
#               'resolución',
#               'salón',
#               'teatro',
#               'álbum'},
#              51: {'actividad',
#               'agua',
#               'ajuste',
#               'amante',
#               'amarillento',
#               'amerindios',
#               'amiloides',
#               'anarcosindicalistas',
#               'and',
#               'anillo',
#               'aniones',
#               'anunciación',
#               'aro',
#               'arseniato',
#               'artículos',
#               'aspecto',
#               'asunto',
#               'atractivos',
#               'auge',
#               'australis',
#               'añadidura',
#               'año',
#               'años',
#               'banda',
#               'bandas',
#               'base',
#               'bases',
#               'basidiomiceto',
#               'basidios',
#               'biógrafo',
#               'bolas',
#               'bordes',
#               'bracket',
#               'bulbo',
#               'buró',
#               'capa',
#               'capacidades',
#               'carrera',
#               'carreras',
#               'casa',
#               'casquillo',
#               'ceremonia',
#               'chismes',
#               'ciervos',
#               'clases',
#               'cobrería',
#               'color',
#               'combate',
#               'combinación',
#               'comité',
#               'compañera',
#               'competencia',
#               'composición',
#               'compuestos',
#               'conferencia',
#               'conjunto',
#               'continuación',
#               'contrato',
#               'cooperación',
#               'crisocola',
#               'cuentas',
#               'cuero',
#               'cuerpos',
#               'cultura',
#               'células',
#               'delegado',
#               'delegados',
#               'director',
#               'dirigentes',
#               'disco',
#               'discurso',
#               'discusiones',
#               'divergencias',
#               'división',
#               'diámetro',
#               'ectomicorriza',
#               'equipo',
#               'especie',
#               'esporas',
#               'estación',
#               'estipe',
#               'estructuras',
#               'explicaciones',
#               'exponerlas',
#               'exterior',
#               'extranjero',
#               'extremidades',
#               'far',
#               'flete',
#               'formación',
#               'formas',
#               'formato',
#               'fosfatos',
#               'frecuencia',
#               'grisáceas',
#               'grosero',
#               'grosor',
#               'grupo',
#               'grupos',
#               'género',
#               'habitantes',
#               'hialinos',
#               'hifas',
#               'historia',
#               'hongos',
#               'importancia',
#               'individualismo',
#               'informe',
#               'instancia',
#               'interés',
#               'investigación',
#               'islas',
#               'jardinero',
#               'lago',
#               'laminillas',
#               'lamélulas',
#               'lanzador',
#               'litos',
#               'llanura',
#               'láminas',
#               'líder',
#               'manifiesto',
#               'marido',
#               'mayoría',
#               'mayorías',
#               'mechones',
#               'meses',
#               'meseta',
#               'micorrizas',
#               'micólogo',
#               'miembros',
#               'militantes',
#               'mineral',
#               'minorías',
#               'movimientos',
#               'muerte',
#               'naturaleza',
#               'nieto',
#               'nombre',
#               'número',
#               'obra',
#               'ocasiones',
#               'ovoide',
#               'padre',
#               'paredes',
#               'pareja',
#               'partial',
#               'partido',
#               'piedra',
#               'piramidales',
#               'plano',
#               'profundidad',
#               'programa',
#               'publicaciones',
#               'publicación',
#               'pueblo',
#               'puntas',
#               'píleo',
#               'razas',
#               'relaciones',
#               'relación',
#               'representante',
#               'requisito',
#               'ribera',
#               'sección',
#               'secretario',
#               'sello',
#               'semanario',
#               'series',
#               'servicios',
#               'siglo',
#               'sindicalismo',
#               'socialismo',
#               'soldadura',
#               'sombreros',
#               'superficie',
#               'supervivencia',
#               'suscripción',
#               'talleres',
#               'tallo',
#               'tamaño',
#               'taxón',
#               'teatro',
#               'temporadas',
#               'tennantita',
#               'the',
#               'tipo',
#               'tirolita',
#               'tomo',
#               'tono',
#               'trabajos',
#               'transversales',
#               'tronco',
#               'trotskismo',
#               'verrugas',
#               'viajes',
#               'vida',
#               'visas',
#               'visitadora',
#               'you',
#               'zonas',
#               'época',
#               'éxito'},
#              36: {'agrietado',
#               'anotadas',
#               'arseniatos',
#               'bizantino',
#               'blanca',
#               'blancas',
#               'castaños',
#               'completos',
#               'discográfico',
#               'emancipada',
#               'escasas',
#               'estrechos',
#               'excepcional',
#               'firme',
#               'francés',
#               'gelatinizada',
#               'hueco',
#               'industriales',
#               'kmDIGITO',
#               'minero',
#               'nacionales',
#               'oceanográfica',
#               'oriental',
#               'osos',
#               'pequeñas',
#               'revolucionario',
#               'rusa',
#               'translúcidas',
#               'umber',
#               'zinovievista',
#               'µm'},
#              6: {'y'},
#              21: {'Crece',
#               'Entra',
#               'Militó',
#               'abstuvo',
#               'basándose',
#               'conoce',
#               'convierte',
#               'convirtió',
#               'crece',
#               'cree',
#               'descubierta',
#               'ejercer',
#               'entró',
#               'fundado',
#               'habita',
#               'ilustró',
#               'interesarse',
#               'introdujo',
#               'jugando',
#               'jugó',
#               'live',
#               'milita',
#               'muestra',
#               'muestran',
#               'obtenido',
#               'pagar',
#               'participa',
#               'permanecen',
#               'permaneció',
#               'produce',
#               'profesa',
#               'publica',
#               'puesto',
#               'rockalbum',
#               'separó',
#               'sitúa',
#               'terminar',
#               'transformado',
#               'ubica',
#               'vivía',
#               'votaron'},
#              4: {'amistad',
#               'asociación',
#               'base',
#               'bordes',
#               'cabo',
#               'carne',
#               'castaño',
#               'ciudad',
#               'clasificación',
#               'colaboración',
#               'competencia',
#               'condición',
#               'congresos',
#               'contactos',
#               'crítica',
#               'depresión',
#               'divergencias',
#               'elipsoidales',
#               'especie',
#               'esporas',
#               'estación',
#               'estafeta',
#               'gira',
#               'gris',
#               'guardia',
#               'localidad',
#               'mediano',
#               'organización',
#               'publicación',
#               'relación',
#               'reunión',
#               'revolución',
#               'similitud',
#               'superficie',
#               'tierra',
#               'venta',
#               'vida',
#               'villa'},
#              67: {'australis',
#               'cortas',
#               'diagonal',
#               'dominicano',
#               'miel',
#               'patagónica',
#               'soviético',
#               'turística'},
#              5: {'abandonando',
#               'acepta',
#               'acercarse',
#               'adherido',
#               'adhiere',
#               'admitido',
#               'afirmando',
#               'album',
#               'alcanzar',
#               'aleja',
#               'anular',
#               'aporta',
#               'aportan',
#               'apoya',
#               'apoyan',
#               'aprende',
#               'aprobar',
#               'aprueba',
#               'asegura',
#               'asiste',
#               'atienden',
#               'beneficia',
#               'buró',
#               'capa',
#               'cargado',
#               'circular',
#               'coincide',
#               'colabora',
#               'communiste',
#               'conocida',
#               'consagró',
#               'considerada',
#               'consiguió',
#               'contribuir',
#               'convexo',
#               'convierte',
#               'critica',
#               'cruzaron',
#               'cubrir',
#               'cuesta',
#               'decayó',
#               'decide',
#               'denuncia',
#               'derrotó',
#               'desarrolla',
#               'desarrolló',
#               'describió',
#               'descrita',
#               'dirigiéndose',
#               'dándole',
#               'efectuar',
#               'efectúa',
#               'elegido',
#               'emitía',
#               'emplazaba',
#               'emplea',
#               'encaja',
#               'encontrar',
#               'encontrarse',
#               'encuentran',
#               'enfrentaron',
#               'enrolla',
#               'entabla',
#               'entra',
#               'examinó',
#               'excluyeron',
#               'existía',
#               'extienden',
#               'firma',
#               'firmando',
#               'flavoconia',
#               'forma',
#               'formalizar',
#               'forman',
#               'formando',
#               'franchetii',
#               'fusca',
#               'grabar',
#               'guía',
#               'habitada',
#               'habitados',
#               'impedir',
#               'impide',
#               'inaugurado',
#               'inauguró',
#               'incluyendo',
#               'incorpora',
#               'instalar',
#               'intentaban',
#               'intentó',
#               'interesan',
#               'jugará',
#               'jugaría',
#               'justificó',
#               'lakorn',
#               'life',
#               'list',
#               'llamado',
#               'llamó',
#               'llavar',
#               'logró',
#               'malaquita',
#               'manteniendo',
#               'mantiene',
#               'mantuvo',
#               'medir',
#               'mide',
#               'miden',
#               'militó',
#               'minimizar',
#               'nombrado',
#               'notado',
#               'obtiene',
#               'opuso',
#               'organizar',
#               'ostentaría',
#               'ouvrière',
#               'participa',
#               'participar',
#               'participaron',
#               'pasar',
#               'pasó',
#               'perdieron',
#               'permitía',
#               'posee',
#               'prefacia',
#               'presenta',
#               'presentó',
#               'presidiendo',
#               'presta',
#               'preveía',
#               'prima',
#               'proporciona',
#               'propusieron',
#               'publica',
#               'publicar',
#               'puesto',
#               'queda',
#               'quedar',
#               'quería',
#               'realiza',
#               'recoger',
#               'reemplazado',
#               'reemplazar',
#               'rendirá',
#               'reparar',
#               'representado',
#               'reside',
#               'resulta',
#               'retoma',
#               'reunió',
#               'revise',
#               'reúnen',
#               'rojizo',
#               'russe',
#               'seguir',
#               'siguen',
#               'together',
#               'toma',
#               'tornería',
#               'translitera',
#               'trasfirió',
#               'trazará',
#               'unen',
#               'visto',
#               'viviendo',
#               'volviéndose',
#               'vuelve'},
#              2: {'acusaciones',
#               'apoyo',
#               'asesinato',
#               'aumento',
#               'ayuda',
#               'ayudante',
#               'banda',
#               'bandas',
#               'bulto',
#               'centenar',
#               'centristas',
#               'colonia',
#               'concepción',
#               'conciencia',
#               'congreso',
#               'contrario',
#               'correcciones',
#               'crítico',
#               'cuerpos',
#               'desarrollo',
#               'diferencia',
#               'dificultades',
#               'eliminación',
#               'especie',
#               'especies',
#               'existencia',
#               'favor',
#               'finales',
#               'grabación',
#               'grabado',
#               'grupo',
#               'hifas',
#               'hiladora',
#               'influencias',
#               'julio',
#               'julion',
#               'junio',
#               'lago',
#               'lecciones',
#               'margen',
#               'marzo',
#               'medida',
#               'miembros',
#               'militantes',
#               'mineral',
#               'misión',
#               'mitad',
#               'mosca',
#               'necesidades',
#               'nombre',
#               'notas',
#               'noviembre',
#               'obra',
#               'obras',
#               'oficio',
#               'padres',
#               'papel',
#               'partida',
#               'partidos',
#               'personajes',
#               'presencia',
#               'promedio',
#               'purga',
#               'raíz',
#               'redacción',
#               'regreso',
#               'restos',
#               'reuniones',
#               'récord',
#               'serie',
#               'shows',
#               'sistema',
#               'sur',
#               'tesis',
#               'tipos',
#               'versiones',
#               'zigóptero',
#               'álbum',
#               'áreas'},
#              69: {'amigos',
#               'bordes',
#               'despachos',
#               'dirigentes',
#               'fundadores',
#               'límites',
#               'millones',
#               'márgenes',
#               'océanos',
#               'remanecientes',
#               'trabajos'},
#              8: {'adhesión',
#               'agua',
#               'algodón',
#               'ancho',
#               'arena',
#               'azul',
#               'basidios',
#               'calderería',
#               'carbonato',
#               'cargas',
#               'color',
#               'construir',
#               'coníferas',
#               'corrector',
#               'dirección',
#               'diámetro',
#               'encuesta',
#               'espesor',
#               'forma',
#               'francés',
#               'frosardismo',
#               'fungi',
#               'fútbol',
#               'género',
#               'hongo',
#               'inteligencia',
#               'investigación',
#               'malversaciones',
#               'mano',
#               'micorrizas',
#               'miradas',
#               'obra',
#               'odonato',
#               'paja',
#               'plantas',
#               'posguerra',
#               'prefacios',
#               'problemas',
#               'rugosidades',
#               'secundaria',
#               'tamaño',
#               'televisión',
#               'temporada',
#               'trébol',
#               'verrugas',
#               'visitantes',
#               'árboles'},
#              0: {'Abu',
#               'Adrien',
#               'Albert',
#               'Alexei',
#               'Alfred',
#               'Alta',
#               'Amanita',
#               'Amanitaceae',
#               'Amédée',
#               'América',
#               'Andrès',
#               'Angeles',
#               'Angels',
#               'Aprovecha',
#               'Argentina',
#               'Argo',
#               'Athiwara',
#               'Austria',
#               'B',
#               'Bodyslam',
#               'Boris',
#               'Borís',
#               'Bugs',
#               'Bélgica',
#               'Cachin',
#               'Calopterix',
#               'Calopterygidae',
#               'Caraglio',
#               'Cardinals',
#               'Carrie',
#               'Castleton',
#               'Central',
#               'Charlesworth',
#               'Christian',
#               'Cibaeñas',
#               'Comité',
#               'Comunista',
#               'Comédie',
#               'Copa',
#               'Coyoacan',
#               'Cruz',
#               'Dai',
#               'David',
#               'Deseado',
#               'Dhabi',
#               'Dique',
#               'Dirección',
#               'Domingo',
#               'Dommanget',
#               'Donovan',
#               'Dunay',
#               'Dunois',
#               'Egon',
#               'Estación',
#               'Eto',
#               'Europa',
#               'Fernand',
#               'Ferrocarril',
#               'Francia',
#               'Française',
#               'Frossard',
#               'Gang',
#               'Gaston',
#               'Gauche',
#               'Geneviève',
#               'Geoff',
#               'Give',
#               'Gras',
#               'Greco',
#               'Greta',
#               'Grigori',
#               'Griot',
#               'Guzmán',
#               'Harry',
#               'Heras',
#               'Hills',
#               'Horak',
#               'Hot',
#               'Huapi',
#               'Hudson',
#               'III',
#               'ISR',
#               'Ibsen',
#               'Ignace',
#               'Impossibles',
#               'Independiente',
#               'Intercontinental',
#               'Internacional',
#               'Internacionales',
#               'It',
#               'José',
#               'Keystone',
#               'Kun',
#               'Kurt',
#               'L',
#               'Laborista',
#               'Lagos',
#               'Lancashire',
#               'Landau',
#               'Lilas',
#               'Limacella',
#               'Lopera',
#               'Loriot',
#               'Losovski',
#               'Louis',
#               'Louisa',
#               'Mamore',
#               'Marguerite',
#               'Maurice',
#               'Mauá',
#               'Molinier',
#               'Monatte',
#               'Monnate',
#               'Montagne',
#               'Monte',
#               'Moscú',
#               'Murmansk',
#               'Music',
#               'México',
#               'N',
#               'Nacional',
#               'Nai',
#               'National',
#               'Naval',
#               'Naville',
#               'Nikolái',
#               'Nin',
#               'Niyai',
#               'Norte',
#               'Not',
#               'Nothofagus',
#               'Oudemansiella',
#               'PCF',
#               'Pampa',
#               'Partido',
#               'París',
#               'Patagónico',
#               'Pepper',
#               'Pierre',
#               'Pollitt',
#               'Potosí',
#               'Profesor',
#               'Prolétarienne',
#               'R',
#               'Radek',
#               'Raymond',
#               'Real',
#               'Reiss',
#               'René',
#               'Ridley',
#               'Roberto',
#               'Rodham',
#               'Rolland',
#               'Rosmer',
#               'Rue',
#               'Rushmore',
#               'Révolution',
#               'SCRA',
#               'SFIC',
#               'Sainte',
#               'Samuel',
#               'Sano',
#               'Santiago',
#               'Sección',
#               'Sheikh',
#               'Sieva',
#               'Silverio',
#               'Stalin',
#               'Stevenson',
#               'Sur',
#               'Suvarin',
#               'Temps',
#               'The',
#               'Thep',
#               'Tito',
#               'Tomás',
#               'Treint',
#               'Trotsky',
#               'Tulloss',
#               'Tungus',
#               'Unidos',
#               'Validae',
#               'Veloz',
#               'Vergeat',
#               'Victor',
#               'Vie',
#               'Wave',
#               'Wellington',
#               'Yessey',
#               'York',
#               'Yugoslavia',
#               'Zayed',
#               'Zelanda',
#               'Zinóviev',
#               'Águilas',
#               'Álvarez',
#               'Éscuela',
#               'Étudiants',
#               'Λίθος',
#               'Дунай',
#               'Ессей',
#               'Острова',
#               'ยาย',
#               'ละ',
#               'เทพน'},
#              63: {'Camus',
#               'Internacional',
#               'Memorial',
#               'Monatte',
#               'Monmousseau',
#               'Souvarine',
#               'Thevenet',
#               'Unidos',
#               'Vanyady'},
#              11: {'allá',
#               'anteriormente',
#               'atrás',
#               'australis',
#               'claramente',
#               'completamente',
#               'cuyo',
#               'deberá',
#               'debería',
#               'densamente',
#               'diecisiete',
#               'diez',
#               'diversas',
#               'e',
#               'enfrentándose',
#               'expcepcionalmente',
#               'explicando',
#               'finalmente',
#               'igualmente',
#               'in',
#               'inicialmente',
#               'intensamente',
#               'justo',
#               'lentamente',
#               'libremente',
#               'loa',
#               'madre',
#               'misteriosamente',
#               'moderadamente',
#               'mouvement',
#               'mutuamente',
#               'naturalmente',
#               'normalmente',
#               'notablemente',
#               'of',
#               'oficialmente',
#               'on',
#               'originalmente',
#               'posteriormente',
#               'radicalmente',
#               'realmente',
#               'reformar',
#               'rápidamente',
#               'totalmente',
#               'típicamente',
#               'u',
#               'º',
#               'únicamente'},
#              10: {'afiliación',
#               'banda',
#               'canción',
#               'capital',
#               'ciudad',
#               'colaboración',
#               'comisión',
#               'composición',
#               'conexión',
#               'definición',
#               'difusión',
#               'enseñanza',
#               'espalda',
#               'estación',
#               'estancia',
#               'familia',
#               'financiación',
#               'forma',
#               'guerra',
#               'herramienta',
#               'joven',
#               'lengua',
#               'literatura',
#               'lucha',
#               'madures',
#               'minoría',
#               'mêlée',
#               'obra',
#               'pintura',
#               'planta',
#               'pradera',
#               'prensa',
#               'reacción',
#               'reparación',
#               'representación',
#               'revista',
#               'revolución',
#               'ruptura',
#               'sección',
#               'seta',
#               'sinonimia',
#               'supervivencia',
#               'tennantita',
#               'tribu',
#               'unanimidad',
#               'unión',
#               'verruga',
#               'vida',
#               'visión',
#               'volva',
#               'votación',
#               'voz'},
#              1: {'Nacido',
#               'abruptamente',
#               'abundantes',
#               'aceptable',
#               'adecuado',
#               'adherido',
#               'adulta',
#               'afinado',
#               'afroamericanos',
#               'alargada',
#               'amarillentas',
#               'amarillo',
#               'amarronados',
#               'americano',
#               'amerimuscaria',
#               'anarquista',
#               'anarquizante',
#               'anotadas',
#               'antiguo',
#               'asiáticos',
#               'atestadas',
#               'atractivo',
#               'australis',
#               'austríaco',
#               'azul',
#               'azurita',
#               'bajas',
#               'barbero',
#               'beneficiosa',
#               'blanca',
#               'blancas',
#               'blanco',
#               'blanquecino',
#               'bobinados',
#               'bolcheviques',
#               'brochantita',
#               'bulbosa',
#               'capacitados',
#               'castaño',
#               'central',
#               'clasificado',
#               'colgado',
#               'compacto',
#               'comunista',
#               'conectados',
#               'conocido',
#               'convexo',
#               'cónicas',
#               'delgadas',
#               'descargado',
#               'descrita',
#               'destructivos',
#               'deñl',
#               'discográfico',
#               'disidente',
#               'ejecutivo',
#               'elevada',
#               'elípticas',
#               'esenciales',
#               'esféricas',
#               'estalinistas',
#               'estudioso',
#               'extensa',
#               'extranjero',
#               'extraordinaria',
#               'ferroviaria',
#               'fijadas',
#               'franceses',
#               'francés',
#               'fundamental',
#               'futuro',
#               'futuros',
#               'gelatinizada',
#               'globalmente',
#               'hialinas',
#               'hidroxilado',
#               'homónimo',
#               'hábil',
#               'importantes',
#               'independenciadel',
#               'inferior',
#               'inglés',
#               'inicial',
#               'inmensa',
#               'intelectual',
#               'internacionales',
#               'internas',
#               'internationalistes',
#               'irregulares',
#               'italiano',
#               'joven',
#               'lejano',
#               'llamado',
#               'locales',
#               'localizadas',
#               'láminas',
#               'macrospora',
#               'madura',
#               'mecánica',
#               'mejores',
#               'micologista',
#               'micorriza',
#               'miel',
#               'minerales',
#               'mojado',
#               'monotonal',
#               'monumental',
#               'máxima',
#               'médica',
#               'nacido',
#               'nacional',
#               'name',
#               'naval',
#               'neozelandesa',
#               'nombrada',
#               'nombrado',
#               'numerosos',
#               'obligatoria',
#               'obrera',
#               'obrero',
#               'ocasionalmente',
#               'orgánica',
#               'orgánicos',
#               'oscuro',
#               'parisinos',
#               'parlamentario',
#               'participantes',
#               'pegajosa',
#               'pequeño',
#               'pequeños',
#               'piel',
#               'planeado',
#               'político',
#               'popular',
#               'postal',
#               'primordial',
#               'principal',
#               'privilegiadas',
#               'profundas',
#               'proletariado',
#               'prolétarienne',
#               'próximas',
#               'pálido',
#               'raro',
#               'real',
#               'rebautizada',
#               'recibidas',
#               'reconocida',
#               'referida',
#               'reformistas',
#               'revolucionarias',
#               'roja',
#               'rugoso',
#               'ruso',
#               'rusos',
#               'révolutionnaires',
#               'sagrada',
#               'seco',
#               'secundario',
#               'seguros',
#               'separada',
#               'sepia',
#               'simbiótica',
#               'sindical',
#               'sindicalista',
#               'socialistas',
#               'socialistes',
#               'songs',
#               'south',
#               'straw',
#               'subpellis',
#               'suizo',
#               'superior',
#               'suprapellis',
#               'surcos',
#               'tailandesa',
#               'taxonómico',
#               'teatral',
#               'tensos',
#               'translated',
#               'transparente',
#               'trotskista',
#               'truncadas',
#               'très',
#               'turísticos',
#               'tácticas',
#               'verosímil',
#               'with',
#               'única'},
#              43: {'Aula',
#               'Black',
#               'Comité',
#               'Departamento',
#               'Dique',
#               'Estadio',
#               'Museo',
#               'Nahuel',
#               'Parque',
#               'Partido'},
#              18: {'On',
#               'activo',
#               'activos',
#               'agrupadas',
#               'basada',
#               'blanquecino',
#               'común',
#               'construido',
#               'cuarto',
#               'cónico',
#               'desasparecidos',
#               'desconocida',
#               'diseminados',
#               'dispuestas',
#               'divididos',
#               'dulce',
#               'encontrado',
#               'estalinistas',
#               'exiliados',
#               'francés',
#               'frecuentes',
#               'impulsada',
#               'inaugurado',
#               'industrial',
#               'internacionales',
#               'leninista',
#               'libre',
#               'mejores',
#               'nacido',
#               'negro',
#               'ofensivo',
#               'pagado',
#               'político',
#               'pronunciado',
#               'publicado',
#               'realizada',
#               'recogidos',
#               'rico',
#               'sexto',
#               'situadas',
#               'ubicada'},
#              64: {'América',
#               'Black',
#               'Créteil',
#               'Droylsden',
#               'Europa',
#               'Moscú',
#               'París',
#               'Patterson',
#               'Rambla',
#               'Rusia',
#               'San'},
#              23: {'Amanita',
#               'Anaheim',
#               'Autónoma',
#               'Buques',
#               'Clubes',
#               'Comisión',
#               'Comité',
#               'Comunista',
#               'Congreso',
#               'DIMAT',
#               'Díez',
#               'Ejecutivo',
#               'Evangelista',
#               'Francesa',
#               'Francia',
#               'II',
#               'Ingalls',
#               'Internacional',
#               'Krai',
#               'Ligas',
#               'Lille',
#               'Magna',
#               'Marbán',
#               'Mundial',
#               'Pedro',
#               'Phalloides',
#               'Prado',
#               'Provincia',
#               'Rosa',
#               'Servicio',
#               'Suiza',
#               'Sur',
#               'australis',
#               'casa',
#               'dessus'},
#              24: {'abetos',
#               'abundantes',
#               'adecuado',
#               'adicionales',
#               'algodonosos',
#               'amiloide',
#               'blanca',
#               'brillante',
#               'constituyente',
#               'contitutivo',
#               'costeras',
#               'cubiertos',
#               'departamentales',
#               'emergente',
#               'estadounidense',
#               'fructíferos',
#               'hidratado',
#               'húmedas',
#               'importante',
#               'jardín',
#               'km²',
#               'libres',
#               'mayores',
#               'musical',
#               'nacional',
#               'norte',
#               'oriundos',
#               'ouvrier',
#               'quebradizo',
#               'salpicado',
#               'sinónimo',
#               'sonora',
#               'unitaria',
#               'única'},
#              34: {'Amanita',
#               'Campeón',
#               'Democrática',
#               'Ejecutivo',
#               'Historia',
#               'Oficina',
#               'Tigres'},
#              20: {'Au',
#               'Censo',
#               'Comité',
#               'Congo',
#               'Ferrocarril',
#               'Irineu',
#               'Komintern',
#               'Licey',
#               'Norte',
#               'Pacífico',
#               'Partido',
#               'Tirol',
#               'género'},
#              58: {'blancos',
#               'cercano',
#               'goles',
#               'gracias',
#               'km²',
#               'm',
#               'micrómetros',
#               'µm'},
#              25: {'acudir',
#               'adhiere',
#               'ajena',
#               'anaranjado',
#               'asistir',
#               'condujo',
#               'construido',
#               'corresponden',
#               'delega',
#               'designa',
#               'enfrentarse',
#               'envía',
#               'expulsado',
#               'frecuentará',
#               'garantizan',
#               'habilitaban',
#               'iban',
#               'irán',
#               'lanza',
#               'leer',
#               'llamada',
#               'llegan',
#               'llegando',
#               'llegar',
#               'llevada',
#               'llevan',
#               'niegan',
#               'opuso',
#               'parecerse',
#               'pertenecían',
#               'reemplaza',
#               'tiende',
#               'transferido',
#               'viajan',
#               'volver'},
#              3: {'a'},
#              73: {'Desaprobado',
#               'africano',
#               'compuesto',
#               'constituido',
#               'cubierta',
#               'formado',
#               'político',
#               'presentada',
#               'recogidas',
#               'reforzado',
#               'suficientes'},
#              49: {'alistamiento',
#               'alrededores',
#               'caballito',
#               'carne',
#               'centro',
#               'cosecretario',
#               'cutícula',
#               'estaciones',
#               'hijos',
#               'historiador',
#               'honor',
#               'indicación',
#               'iniciativa',
#               'isleños',
#               'jugador',
#               'materiales',
#               'miembro',
#               'miembros',
#               'militantes',
#               'obras',
#               'reuniones',
#               'rosa',
#               'soldados',
#               'superficie',
#               'árboles'},
#              26: {'abuelo',
#               'amarillento',
#               'asesinato',
#               'años',
#               'campeonato',
#               'campeones',
#               'centro',
#               'comunismo',
#               'country',
#               'editor',
#               'electricidad',
#               'exámenes',
#               'huelgas',
#               'italiano',
#               'ocasiones',
#               'partido',
#               'principios',
#               'razas',
#               'región',
#               'rock',
#               'sindicalistas',
#               'socialistas',
#               'tamaño',
#               'testimonios',
#               'tronco'},
#              50: {'o'},
#              61: {'clandestina',
#               'clásico',
#               'hidrotermales',
#               'inferior',
#               'nmombre',
#               'oficioso',
#               'rural',
#               'salido',
#               'sindical',
#               'venenoso'},
#              12: {'arcángel',
#               'ascenso',
#               'año',
#               'buró',
#               'camerunés',
#               'canon',
#               'caso',
#               'centro',
#               'clima',
#               'comité',
#               'congreso',
#               'crecimiento',
#               'encuentro',
#               'equipaje',
#               'espécimen',
#               'estipe',
#               'funk',
#               'furgón',
#               'género',
#               'hombre',
#               'hongo',
#               'indirecto',
#               'interesado',
#               'joven',
#               'libro',
#               'margen',
#               'micólogo',
#               'nombre',
#               'paraje',
#               'partido',
#               'periódico',
#               'petit',
#               'pop',
#               'puesto',
#               'píleo',
#               'ruso',
#               'siglo',
#               'sindicato',
#               'sitio',
#               'teatro',
#               'territorio',
#               'tomo',
#               'tronco',
#               'típico',
#               'área'},
#              47: {'Alfred',
#               'Awards',
#               'Bretaña',
#               'Bujarín',
#               'CGT',
#               'Callejas',
#               'Comunista',
#               'Fayod',
#               'Inglés',
#               'Khongmalai',
#               'Lepetit',
#               'Leptospermum',
#               'Monatte',
#               'Montevideo',
#               'Norte',
#               'Pegler',
#               'Reparaciones',
#               'Rosmer',
#               'Trotsky',
#               'Up',
#               'Vérité',
#               'York',
#               'Zinóviev',
#               'เสนาะ'},
#              59: {'crea',
#               'definió',
#               'difiere',
#               'encontrarse',
#               'firma',
#               'forma',
#               'ganaron',
#               'lanzaron',
#               'mantener',
#               'miden',
#               'obtener',
#               'redujo',
#               'uan'},
#              7: {'anarquismo',
#               'anillo',
#               'arte',
#               'buró',
#               'campeonato',
#               'cobre',
#               'comité',
#               'cretense',
#               'desierto',
#               'diablo',
#               'estipe',
#               'griego',
#               'grupo',
#               'género',
#               'lago',
#               'margen',
#               'material',
#               'matrimonio',
#               'micólogo',
#               'movimiento',
#               'mundo',
#               'nivel',
#               'norte',
#               'núcleo',
#               'partido',
#               'periódico',
#               'politburó',
#               'píleo',
#               'ramal',
#               'ruso',
#               'régimen',
#               'río',
#               'sur',
#               'torneo',
#               'triunfo',
#               'tronco'},
#              39: {'Comunista',
#               'Dunay',
#               'Eno',
#               'España',
#               'Franchet',
#               'Francia',
#               'Imposibles',
#               'Internacional',
#               'Lena',
#               'Montrouge',
#               'Nelson',
#               'París',
#               'Patagónico',
#               'Rotoiti',
#               'Stevenson',
#               'Trotsky',
#               'Turquía'},
#              54: {'Beni',
#               'Borís',
#               'Kronstadt',
#               'María',
#               'Mayo',
#               'Milán',
#               'Stevenson',
#               'África'},
#              75: {'y'},
#              19: {'absorción',
#               'acción',
#               'alteración',
#               'arquitectura',
#               'clase',
#               'clasificación',
#               'comisión',
#               'conferencia',
#               'creación',
#               'declaración',
#               'difusión',
#               'dirección',
#               'década',
#               'escritura',
#               'estación',
#               'estructura',
#               'excepción',
#               'figura',
#               'idea',
#               'mayoría',
#               'mitad',
#               'música',
#               'necesidad',
#               'organización',
#               'política',
#               'posibilidad',
#               'punta',
#               'recuperación',
#               'redacción',
#               'represión',
#               'rosa',
#               'situación',
#               'volva',
#               'zona'},
#              55: {'amiloides',
#               'ascenso',
#               'bases',
#               'cobre',
#               'colabora',
#               'células',
#               'ensayos',
#               'firma',
#               'folk',
#               'librepensadores',
#               'operacionales',
#               'particulares',
#               'pesca',
#               'sindicato',
#               'socialistas',
#               'subcampeones',
#               'vanadatos',
#               'vuelta',
#               'zorros'},
#              13: {'A',
#               'Albert',
#               'Alfred',
#               'Amanita',
#               'América',
#               'Béisbol',
#               'Construcciones',
#               'Francia',
#               'Giacomo',
#               'Hot',
#               'Karl',
#               'Kool',
#               'Krasnoyarsk',
#               'Lenin',
#               'Lyon',
#               'Láptev',
#               'Macorís',
#               'Madrid',
#               'Material',
#               'Mauá',
#               'Melzer',
#               'Molinier',
#               'Monnate',
#               'Moscú',
#               'Oro',
#               'Pando',
#               'Pollitt',
#               'Puerto',
#               'Rensselaer',
#               'Romain',
#               'Rosa',
#               'Rusia',
#               'Santa',
#               'Santo',
#               'Sousa',
#               'Strunz',
#               'Suvarin',
#               'Tailandia',
#               'Tiziano',
#               'Tours',
#               'Treint',
#               'Trotski',
#               'Trotsky',
#               'Zimmerwald'},
#              48: {'borde',
#               'centro',
#               'dialecto',
#               'margen',
#               'responsable',
#               'sistema',
#               'valle'},
#              31: {'base',
#               'carne',
#               'ciudad',
#               'desembocadura',
#               'dictadura',
#               'fotosíntesis',
#               'izquierda',
#               'orilla',
#               'participación',
#               'región',
#               'superficie'},
#              71: {'agua',
#               'alto',
#               'altura',
#               'ancho',
#               'broches',
#               'calcio',
#               'herrero',
#               'ida',
#               'imprenta',
#               'investigación',
#               'vacaciones'},
#              38: {'abril',
#               'bateo',
#               'corrector',
#               'diciembre',
#               'estudiantes',
#               'febrero',
#               'fructificación',
#               'guerra',
#               'julio',
#               'noviembre',
#               'observación',
#               'octubre',
#               'oxidación',
#               'restos',
#               'rock'},
#              37: {'alrededores',
#               'asuntos',
#               'ayuntamientos',
#               'años',
#               'bolcheviques',
#               'bordes',
#               'bosques',
#               'correctores',
#               'crímenes',
#               'círculos',
#               'delegados',
#               'dirigentes',
#               'discursos',
#               'encuentros',
#               'géneros',
#               'hongos',
#               'ingresos',
#               'líderes',
#               'militantes',
#               'minoritarios',
#               'niños',
#               'opositores',
#               'pasajeros',
#               'países',
#               'problemas',
#               'puntos',
#               'temas',
#               'yacimientos'},
#              28: {'Apodado',
#               'Habilitado',
#               'I',
#               'Inicialmente',
#               'Macroscópicamente',
#               'O',
#               'Suele',
#               'ด',
#               'นาย',
#               'ล',
#               'อน',
#               'า'},
#              35: {'amarillento',
#               'asociado',
#               'blanco',
#               'cercano',
#               'cónicas',
#               'esféricos',
#               'favorable',
#               'fijados',
#               'hostil',
#               'pacifista',
#               'pequeño',
#               'perpendiculares',
#               'perteneciente',
#               'simple',
#               'tradicionales'},
#              30: {'y'},
#              66: {'conservada', 'fallecido', 'pálidas', 'reelegido'},
#              40: {'acusa',
#               'carpintería',
#               'consisten',
#               'desapareció',
#               'dimite',
#               'encargan',
#               'iba',
#               'manchan',
#               'midiendo',
#               'procede',
#               'proveyó',
#               'retira',
#               'retracta'},
#              57: {'Anima',
#               'Aparecerían',
#               'Apoya',
#               'Clasificaron',
#               'Defiende',
#               'Destacan',
#               'Finalizado',
#               'Firmaron',
#               'Formaba',
#               'Ocupa',
#               'Organiza',
#               'Produce',
#               'Recibe',
#               'Viajan',
#               'ได'},
#              32: {'Armamento',
#               'Asia',
#               'Atlético',
#               'B',
#               'Balón',
#               'Béla',
#               'Françoise',
#               'Lefebvre',
#               'Lenin',
#               'Marguerite',
#               'Martov',
#               'Mary',
#               'Nothofagus',
#               'Pierre',
#               'Real',
#               'Rosmer',
#               'Sur',
#               'Suvarin',
#               'Tintoretto',
#               'Universitario',
#               'Vaca',
#               'Young'},
#              41: {'concepto',
#               'condado',
#               'congreso',
#               'despacho',
#               'discurso',
#               'juego',
#               'mar',
#               'marco',
#               'negocio',
#               'periódico',
#               'principio',
#               'progrma',
#               'pseudónimo',
#               'reactivo',
#               'recibo',
#               'seno',
#               'sonido',
#               'tallo',
#               'tamaño',
#               'tutor'},
#              16: {'Armada',
#               'Batalla',
#               'Biblia',
#               'CGT',
#               'CGTU',
#               'Conferencia',
#               'Conmebol',
#               'Copa',
#               'Cuarta',
#               'FIFA',
#               'Federación',
#               'Histoire',
#               'IC',
#               'IIIa',
#               'ISR',
#               'Internacional',
#               'Isla',
#               'Liga',
#               'República',
#               'Révolution',
#               'SFIC',
#               'Tierra',
#               'UEFA',
#               'Universidad',
#               'VO',
#               'Verité',
#               'Virgen'},
#              80: {'eje',
#               'embarcadero',
#               'flete',
#               'premio',
#               'regreso',
#               'vegetal',
#               'viajes'},
#              22: {'asociación',
#               'cadenas',
#               'contacto',
#               'cronista',
#               'desacuerdo',
#               'destino',
#               'ell',
#               'hits',
#               'idioma',
#               'inglés',
#               'muestras',
#               'ocasiones',
#               'particular',
#               'peces',
#               'procedencia',
#               'promoción',
#               'tailandés',
#               'torno',
#               'transferencias',
#               'verano',
#               'vueltas'},
#              53: {'A',
#               'XVII',
#               'XVIII',
#               'พอ',
#               'ม',
#               'ส',
#               'หร',
#               'อ',
#               'เบ',
#               'เปล'},
#              27: {'Censo'},
#              9: {'ingresos'},
#              14: {'medios'},
#              15: {'hogar'},
#              33: {'localidad'},
#              42: {'familia'},
#              45: {'asociasiones',
#               'años',
#               'carrera',
#               'centímetros',
#               'equipos',
#               'hits',
#               'juegos',
#               'países',
#               'turnos',
#               'º'},
#              56: {'A', 'À', 'ซ'},
#              46: {'abril',
#               'cotejos',
#               'diciembre',
#               'enero',
#               'forma',
#               'jefe',
#               'junio',
#               'mayo',
#               'noviembre',
#               'verano'},
#              44: {'Barón',
#               'Boletín',
#               'Comité',
#               'Congreso',
#               'Inter',
#               'Mazembe',
#               'Testamento'},
#              70: {'décimo',
#               'escasas',
#               'extranjeros',
#               'grisáceos',
#               'love',
#               'nutrientes',
#               'tecnológicas'},
#              79: {'diciembre', 'reunión', 'trébol'},
#              77: {'abundantes', 'dicha', 'micelio', 'pequeñas', 'vasta'},
#              60: {'Deseado',
#               'Inglaterra',
#               'Rosmer',
#               'Sieva',
#               'Suiza',
#               'Trotsky',
#               'Unidos'},
#              74: {'directamente', 'igualmente', 'suavemente'},
#              62: {'abrupta',
#               'creía',
#               'defiende',
#               'especificó',
#               'indican',
#               'pensaba',
#               'pide',
#               'remarca',
#               'significa',
#               'sugiere'},
#              65: {'artículos',
#               'autores',
#               'cargo',
#               'concurso',
#               'hongo',
#               'piramidales',
#               'puesto',
#               'sindicalista',
#               'texto'},
#              72: {'Alfred', 'Rosmer'},
#              52: {'and',
#               'du',
#               'flycap',
#               'guilty',
#               'nouveaux',
#               'of',
#               'ouvrière',
#               'plao',
#               'the',
#               'vida',
#               'virgo',
#               'à'},
#              76: {'bosque', 'grupo', 'holotipo', 'norte', 'sindicato'},
#              81: {'especie', 'primavera', 'revolución', 'serie', 'volva'},
#              29: {'a'},
#              78: {'imparables', 'pleno', 'ruso', 'vivo'},
#              68: {'agencias', 'centímetros', 'cm', 'milímetros', 'mm', 'µm'}})

# %%
with open(r"../pickles/clustersOLDFEAT.pkl", "wb") as fd:
    pickle.dump(clusters, fd)

# %%
Sum_of_squared_distances = []
K = range(30,100)
for k in tqdm(K):
    km = KMeans(n_clusters=k)
    km = km.fit(v_rd)
    Sum_of_squared_distances.append(km.inertia_)
# Out:
#   0%|          | 0/70 [00:00<?, ?it/s]
#   1%|▏         | 1/70 [00:00<00:49,  1.38it/s]
#   3%|▎         | 2/70 [00:01<00:50,  1.34it/s]
#   4%|▍         | 3/70 [00:02<00:49,  1.35it/s]
#   6%|▌         | 4/70 [00:03<00:49,  1.33it/s]
#   7%|▋         | 5/70 [00:03<00:48,  1.35it/s]
#   9%|▊         | 6/70 [00:04<00:49,  1.30it/s]
#  10%|█         | 7/70 [00:05<00:53,  1.18it/s]
#  11%|█▏        | 8/70 [00:06<00:53,  1.16it/s]
#  13%|█▎        | 9/70 [00:07<00:51,  1.18it/s]
#  14%|█▍        | 10/70 [00:08<00:52,  1.15it/s]
#  16%|█▌        | 11/70 [00:09<00:51,  1.15it/s]
#  17%|█▋        | 12/70 [00:10<00:52,  1.10it/s]
#  19%|█▊        | 13/70 [00:11<00:52,  1.08it/s]
#  20%|██        | 14/70 [00:12<00:52,  1.06it/s]
#  21%|██▏       | 15/70 [00:13<00:52,  1.05it/s]
#  23%|██▎       | 16/70 [00:14<00:54,  1.01s/it]
#  24%|██▍       | 17/70 [00:15<00:53,  1.01s/it]
#  26%|██▌       | 18/70 [00:16<00:54,  1.04s/it]
#  27%|██▋       | 19/70 [00:17<00:54,  1.07s/it]
#  29%|██▊       | 20/70 [00:18<00:54,  1.09s/it]
#  30%|███       | 21/70 [00:19<00:55,  1.12s/it]
#  31%|███▏      | 22/70 [00:20<00:54,  1.14s/it]
#  33%|███▎      | 23/70 [00:22<00:55,  1.18s/it]
#  34%|███▍      | 24/70 [00:23<00:55,  1.21s/it]
#  36%|███▌      | 25/70 [00:24<00:57,  1.27s/it]
#  37%|███▋      | 26/70 [00:26<00:59,  1.34s/it]
#  39%|███▊      | 27/70 [00:27<00:56,  1.30s/it]
#  40%|████      | 28/70 [00:29<00:56,  1.35s/it]
#  41%|████▏     | 29/70 [00:30<00:57,  1.40s/it]
#  43%|████▎     | 30/70 [00:32<00:56,  1.41s/it]
#  44%|████▍     | 31/70 [00:33<00:55,  1.41s/it]
#  46%|████▌     | 32/70 [00:35<00:57,  1.51s/it]
#  47%|████▋     | 33/70 [00:36<00:57,  1.54s/it]
#  49%|████▊     | 34/70 [00:38<00:54,  1.51s/it]
#  50%|█████     | 35/70 [00:39<00:52,  1.51s/it]
#  51%|█████▏    | 36/70 [00:41<00:52,  1.55s/it]
#  53%|█████▎    | 37/70 [00:43<00:52,  1.58s/it]
#  54%|█████▍    | 38/70 [00:44<00:51,  1.60s/it]
#  56%|█████▌    | 39/70 [00:46<00:50,  1.61s/it]
#  57%|█████▋    | 40/70 [00:48<00:48,  1.63s/it]
#  59%|█████▊    | 41/70 [00:50<00:50,  1.75s/it]
#  60%|██████    | 42/70 [00:51<00:48,  1.73s/it]
#  61%|██████▏   | 43/70 [00:53<00:47,  1.77s/it]
#  63%|██████▎   | 44/70 [00:55<00:47,  1.81s/it]
#  64%|██████▍   | 45/70 [00:57<00:46,  1.87s/it]
#  66%|██████▌   | 46/70 [00:59<00:45,  1.90s/it]
#  67%|██████▋   | 47/70 [01:01<00:43,  1.88s/it]
#  69%|██████▊   | 48/70 [01:03<00:42,  1.95s/it]
#  70%|███████   | 49/70 [01:05<00:41,  2.00s/it]
#  71%|███████▏  | 50/70 [01:07<00:39,  1.98s/it]
#  73%|███████▎  | 51/70 [01:09<00:37,  1.99s/it]
#  74%|███████▍  | 52/70 [01:11<00:35,  1.98s/it]
#  76%|███████▌  | 53/70 [01:13<00:34,  2.02s/it]
#  77%|███████▋  | 54/70 [01:15<00:32,  2.02s/it]
#  79%|███████▊  | 55/70 [01:17<00:31,  2.10s/it]
#  80%|████████  | 56/70 [01:19<00:28,  2.07s/it]
#  81%|████████▏ | 57/70 [01:21<00:26,  2.06s/it]
#  83%|████████▎ | 58/70 [01:24<00:25,  2.13s/it]
#  84%|████████▍ | 59/70 [01:26<00:23,  2.18s/it]
#  86%|████████▌ | 60/70 [01:28<00:21,  2.19s/it]
#  87%|████████▋ | 61/70 [01:30<00:19,  2.19s/it]
#  89%|████████▊ | 62/70 [01:33<00:17,  2.19s/it]
#  90%|█████████ | 63/70 [01:35<00:15,  2.23s/it]
#  91%|█████████▏| 64/70 [01:37<00:13,  2.22s/it]
#  93%|█████████▎| 65/70 [01:39<00:11,  2.23s/it]
#  94%|█████████▍| 66/70 [01:42<00:09,  2.26s/it]
#  96%|█████████▌| 67/70 [01:44<00:06,  2.30s/it]
#  97%|█████████▋| 68/70 [01:46<00:04,  2.29s/it]
#  99%|█████████▊| 69/70 [01:49<00:02,  2.34s/it]
# 100%|██████████| 70/70 [01:51<00:00,  1.60s/it]

# %%
import matplotlib.pyplot as plt
plt.plot(K, Sum_of_squared_distances, 'bx-')
plt.xlabel('k')
plt.ylabel('Sum_of_squared_distances')
plt.title('Elbow Method For Optimal k')
plt.show()
